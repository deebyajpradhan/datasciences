# %%
#we need to install the psycopg2 module to connect to postgresql
import psycopg2

# %%
hostname='localhost'
database='xxxxx'
username='xxxxx'
pwd='xxx@xx'
port_id=5432

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\djpra\Documents\DS\Practice Datasets\Live.csv')

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table',engine)

# %%
sqldf=pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#       index                          status_id status_type status_published  \
# 0         0   246675545449582_1649696485147474       video   4/22/2018 6:00
# 1         1   246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2         2   246675545449582_1648730588577397       video   4/21/2018 6:17
# 3         3   246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4         4   246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...     ...                                ...         ...              ...
# 7045   7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046   7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047   7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048   7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049   7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
# ...

# %%
from sqlalchemy import create_engine
# Postgres username, password, and database name
POSTGRES_ADDRESS = 'localhost' 
POSTGRES_PORT = 'xxxx'
POSTGRES_USERNAME = 'xxxxx' 
POSTGRES_PASSWORD = 'xxxx@xx' 
# A long string that contains the necessary Postgres login information
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(username=POSTGRES_USERNAME,password=POSTGRES_PASSWORD,ipaddress=POSTGRES_ADDRESS,port=POSTGRES_PORT,dbname='course_data'))
# Create the connection
cnx = create_engine(postgres_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d97b835c740f> in <module>
#       8 postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(username=POSTGRES_USERNAME,password=POSTGRES_PASSWORD,ipaddress=POSTGRES_ADDRESS,port=POSTGRES_PORT,dbname='course_data'))
#       9 # Create the connection
# ---> 10 cnx = create_engine(postgres_str)
#
# <string> in create_engine(url, **kwargs)
#
# ~\Documents\DS\anaconda\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~\Documents\DS\anaconda\lib\site-packages\sqlalchemy\engine\create.py in create_engine(url, **kwargs)
#     516
# ...

# %%
df1=pd.read_sql_query('''SELECT * FROM employees;''', cnx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e607cc240346> in <module>
# ----> 1 df1=pd.read_sql_query('''SELECT * FROM employees;''', cnx)
#
# NameError: name 'cnx' is not defined

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined
