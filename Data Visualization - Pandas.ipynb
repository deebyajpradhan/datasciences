# %%
import numpy as np
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(x=df1.index.name,y='B',figsize=(12,3),lw=2)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(5500,2),columns=['a','b'])

# %%
df
# Out:
#              a         b
# 0     0.737106  0.043642
# 1    -1.520370 -0.061675
# 2    -0.593642  1.381049
# 3    -1.025512 -0.240472
# 4     0.889731  0.264851
# ...        ...       ...
# 5495  0.212415  0.264538
# 5496 -0.426454 -0.428719
# 5497 -0.103515  1.077158
# 5498  0.730021 -0.063744
# 5499  0.344736  0.875733
#
# [5500 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['b'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['b'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
